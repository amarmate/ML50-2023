# %% [markdown]
# # 1. Import the needed libraries

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# data partition
from sklearn.model_selection import train_test_split

#filter methods
# spearman 
# chi-square
import scipy.stats as stats
from scipy.stats import chi2_contingency

#wrapper methods
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.feature_selection import RFE


# embedded methods
from sklearn.linear_model import LassoCV

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 2. Import data

# %%
sample_submission = pd.read_csv("C:/Users/duart/Downloads/sample_submission.csv")
test = pd.read_csv("C:/Users/duart/Downloads/test.csv")
train = pd.read_csv("C:/Users/duart/Downloads/train.csv")

# %% [markdown]
# # 3. Explore the data

# %%
sample_submission.head()
# Out:
#    encounter_id readmitted_binary
# 0        499502                No
# 1        447319                No
# 2        309126               Yes
# 3        181183               Yes
# 4        359339                No

# %%
sample_submission.tail()
# Out:
#        encounter_id readmitted_binary
# 30525        451150                No
# 30526        549298               Yes
# 30527        327586               Yes
# 30528        351214               Yes
# 30529        914270               Yes

# %%
test.head()
# Out:
#    encounter_id country  patient_id             race gender      age weight  \
# 0        499502     USA   103232799        Caucasian   Male  [80-90)      ?
# 1        447319     USA    93395304        Caucasian   Male  [20-30)      ?
# 2        309126     USA     6281586  AfricanAmerican   Male  [30-40)      ?
# 3        181183     USA    67381308        Caucasian   Male  [50-60)      ?
# 4        359339     USA    71670204        Caucasian   Male  [60-70)      ?
#
#   payer_code  outpatient_visits_in_previous_year  \
# 0         HM                                   0
# 1         HM                                   0
# 2          ?                                   0
# 3         BC                                   0
# 4          ?                                   0
#
#    emergency_visits_in_previous_year  ...  number_of_medications  \
# 0                                  0  ...                     14
# 1                                  0  ...                      7
# 2                                  0  ...                     12
# 3                                  0  ...                     16
# 4                                  0  ...                     10
#
#   primary_diagnosis secondary_diagnosis  additional_diagnosis  \
# 0               491                 414                   250
# 1            250.13                  70                   794
# 2               786               250.6                   536
# 3               820                 873                  E884
# 4               599                 427                   414
#
#   number_diagnoses glucose_test_result  a1c_test_result  \
# 0                6                 NaN              NaN
# 1                7                >300              NaN
# 2                6                 NaN              NaN
# 3                9                 NaN              NaN
# 4                9                 NaN              NaN
#
#    change_in_meds_during_hospitalization  prescribed_diabetes_meds  \
# 0                                     No                       Yes
# 1                                     No                        No
# 2                                     No                       Yes
# 3                                     Ch                       Yes
# 4                                     No                       Yes
#
#                               medication
# 0                          ['metformin']
# 1                                     []
# 2                            ['insulin']
# 3  ['metformin', 'glyburide', 'insulin']
# 4                          ['metformin']
#
# [5 rows x 29 columns]

# %%
test.tail()
# Out:
#        encounter_id country  patient_id       race  gender      age weight  \
# 30525        451150     USA    85707450  Caucasian    Male  [70-80)      ?
# 30526        549298     USA      328887  Caucasian    Male  [60-70)      ?
# 30527        327586     USA    21915459  Caucasian  Female  [80-90)      ?
# 30528        351214     USA    17823546  Caucasian    Male      NaN      ?
# 30529        914270     USA    42043239  Caucasian  Female  [60-70)      ?
#
#       payer_code  outpatient_visits_in_previous_year  \
# 30525         HM                                   0
# 30526          ?                                   0
# 30527          ?                                   0
# 30528         MC                                   0
# 30529         MD                                   0
#
#        emergency_visits_in_previous_year  ...  number_of_medications  \
# 30525                                  0  ...                     11
# 30526                                  0  ...                     19
# 30527                                  0  ...                     22
# 30528                                  0  ...                     21
# 30529                                  0  ...                     11
#
#       primary_diagnosis secondary_diagnosis  additional_diagnosis  \
# 30525               584                 276                   276
# 30526               428              250.83                   276
# 30527               996                 403                   250
# 30528               153                 780                   285
# 30529               486                   ?                   428
#
#       number_diagnoses glucose_test_result  a1c_test_result  \
# 30525                9                 NaN              NaN
# 30526                9                 NaN              NaN
# 30527                6                 NaN              NaN
# 30528                5                 NaN               >7
# 30529                8                 NaN              NaN
#
#        change_in_meds_during_hospitalization  prescribed_diabetes_meds  \
# 30525                                     No                        No
# 30526                                     No                       Yes
# 30527                                     No                       Yes
# 30528                                     Ch                       Yes
# 30529                                     No                       Yes
#
#                                      medication
# 30525                                        []
# 30526                               ['insulin']
# 30527                               ['insulin']
# 30528  ['glipizide', 'pioglitazone', 'insulin']
# 30529                          ['pioglitazone']
#
# [5 rows x 29 columns]

# %%
train.head()
# Out:
#    encounter_id country  patient_id             race  gender      age weight  \
# 0        533253     USA       70110        Caucasian  Female  [70-80)      ?
# 1        426224     USA    29775006  AfricanAmerican    Male  [50-60)      ?
# 2        634063     USA    80729253        Caucasian  Female  [60-70)      ?
# 3        890610     USA     2919042  AfricanAmerican    Male  [60-70)      ?
# 4        654194     USA    84871971        Caucasian  Female  [70-80)      ?
#
#   payer_code  outpatient_visits_in_previous_year  \
# 0          ?                                   0
# 1          ?                                   0
# 2          ?                                   0
# 3         MC                                   0
# 4         HM                                   1
#
#    emergency_visits_in_previous_year  ...  secondary_diagnosis  \
# 0                                  0  ...                  276
# 1                                  0  ...                  785
# 2                                  0  ...                  135
# 3                                  0  ...                  562
# 4                                  0  ...                  599
#
#   additional_diagnosis number_diagnoses  glucose_test_result a1c_test_result  \
# 0                  466                8                  NaN             NaN
# 1                  162                9                  NaN             NaN
# 2                  250                6                  NaN             NaN
# 3                  455                5                  NaN             NaN
# 4                  428                9                  NaN             NaN
#
#   change_in_meds_during_hospitalization  prescribed_diabetes_meds  \
# 0                                    No                        No
# 1                                    No                       Yes
# 2                                    Ch                       Yes
# 3                                    No                        No
# 4                                    No                        No
#
#                    medication  readmitted_binary  readmitted_multiclass
# 0                          []                 No               >30 days
# 1                 ['insulin']                 No                     No
# 2  ['glimepiride', 'insulin']                 No                     No
# 3                          []                 No                     No
# 4                          []                 No               >30 days
#
# [5 rows x 31 columns]

# %%
train.tail()
# Out:
#        encounter_id country  patient_id             race  gender      age  \
# 71231        660160     USA    24531381  AfricanAmerican  Female  [80-90)
# 71232        826429     USA     4663818  AfricanAmerican  Female  [70-80)
# 71233        332030     USA    23397147        Caucasian  Female  [60-70)
# 71234        757560     USA    52161750        Caucasian    Male  [60-70)
# 71235        459757     USA    88410897        Caucasian    Male  [70-80)
#
#       weight payer_code  outpatient_visits_in_previous_year  \
# 71231      ?         MC                                   0
# 71232      ?          ?                                   0
# 71233      ?          ?                                   0
# 71234      ?         BC                                   0
# 71235      ?         BC                                   0
#
#        emergency_visits_in_previous_year  ...  secondary_diagnosis  \
# 71231                                  1  ...                  786
# 71232                                  0  ...                  197
# 71233                                  2  ...                  491
# 71234                                  0  ...                  157
# 71235                                  0  ...                  250
#
#       additional_diagnosis number_diagnoses  glucose_test_result  \
# 71231                  250                9                  NaN
# 71232                  V66                6                  NaN
# 71233                  276                9                 >300
# 71234                250.8                5                  NaN
# 71235                  401                8                  NaN
#
#       a1c_test_result change_in_meds_during_hospitalization  \
# 71231              >7                                    Ch
# 71232              >7                                    Ch
# 71233             NaN                                    Ch
# 71234             NaN                                    Ch
# 71235             NaN                                    Ch
#
#        prescribed_diabetes_meds                             medication  \
# 71231                       Yes  ['metformin', 'glyburide', 'insulin']
# 71232                       Yes             ['metformin', 'glyburide']
# 71233                       Yes               ['glyburide', 'insulin']
# 71234                       Yes               ['glyburide', 'insulin']
# 71235                       Yes                            ['insulin']
#
#        readmitted_binary  readmitted_multiclass
# 71231                 No                     No
# 71232                 No                     No
# 71233                Yes               <30 days
# 71234                 No                     No
# 71235                 No               >30 days
#
# [5 rows x 31 columns]

# %%
sample_submission.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30530 entries, 0 to 30529
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   encounter_id       30530 non-null  int64
#  1   readmitted_binary  30530 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 477.2+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30530 entries, 0 to 30529
# Data columns (total 29 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   encounter_id                           30530 non-null  int64
#  1   country                                30530 non-null  object
#  2   patient_id                             30530 non-null  int64
#  3   race                                   28996 non-null  object
#  4   gender                                 30530 non-null  object
#  5   age                                    28999 non-null  object
#  6   weight                                 30530 non-null  object
#  7   payer_code                             30530 non-null  object
#  8   outpatient_visits_in_previous_year     30530 non-null  int64
#  9   emergency_visits_in_previous_year      30530 non-null  int64
#  10  inpatient_visits_in_previous_year      30530 non-null  int64
#  11  admission_type                         28945 non-null  object
#  12  medical_specialty                      30530 non-null  object
#  13  average_pulse_bpm                      30530 non-null  int64
#  14  discharge_disposition                  29429 non-null  object
#  15  admission_source                       28467 non-null  object
#  16  length_of_stay_in_hospital             30530 non-null  int64
#  17  number_lab_tests                       30530 non-null  int64
#  18  non_lab_procedures                     30530 non-null  int64
#  19  number_of_medications                  30530 non-null  int64
#  20  primary_diagnosis                      30530 non-null  object
#  21  secondary_diagnosis                    30530 non-null  object
#  22  additional_diagnosis                   30530 non-null  object
#  23  number_diagnoses                       30530 non-null  int64
#  24  glucose_test_result                    1658 non-null   object
#  25  a1c_test_result                        5102 non-null   object
#  26  change_in_meds_during_hospitalization  30530 non-null  object
#  27  prescribed_diabetes_meds               30530 non-null  object
#  28  medication                             30530 non-null  object
# dtypes: int64(11), object(18)
# memory usage: 6.8+ MB

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71236 entries, 0 to 71235
# Data columns (total 31 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   encounter_id                           71236 non-null  int64
#  1   country                                71236 non-null  object
#  2   patient_id                             71236 non-null  int64
#  3   race                                   67682 non-null  object
#  4   gender                                 71236 non-null  object
#  5   age                                    67679 non-null  object
#  6   weight                                 71236 non-null  object
#  7   payer_code                             71236 non-null  object
#  8   outpatient_visits_in_previous_year     71236 non-null  int64
#  9   emergency_visits_in_previous_year      71236 non-null  int64
#  10  inpatient_visits_in_previous_year      71236 non-null  int64
#  11  admission_type                         67530 non-null  object
#  12  medical_specialty                      71236 non-null  object
#  13  average_pulse_bpm                      71236 non-null  int64
#  14  discharge_disposition                  68646 non-null  object
#  15  admission_source                       66518 non-null  object
#  16  length_of_stay_in_hospital             71236 non-null  int64
#  17  number_lab_tests                       71236 non-null  int64
#  18  non_lab_procedures                     71236 non-null  int64
#  19  number_of_medications                  71236 non-null  int64
#  20  primary_diagnosis                      71236 non-null  object
#  21  secondary_diagnosis                    71236 non-null  object
#  22  additional_diagnosis                   71236 non-null  object
#  23  number_diagnoses                       71236 non-null  int64
#  24  glucose_test_result                    3688 non-null   object
#  25  a1c_test_result                        11916 non-null  object
#  26  change_in_meds_during_hospitalization  71236 non-null  object
#  27  prescribed_diabetes_meds               71236 non-null  object
#  28  medication                             71236 non-null  object
#  29  readmitted_binary                      71236 non-null  object
#  30  readmitted_multiclass                  71236 non-null  object
# dtypes: int64(11), object(20)
# memory usage: 16.8+ MB

# %%
sample_submission.describe(include =['O'])
# Out:
#        readmitted_binary
# count              30530
# unique                 2
# top                   No
# freq               15335

# %%
test.describe()
# Out:
#         encounter_id    patient_id  outpatient_visits_in_previous_year  \
# count   30530.000000  3.053000e+04                        30530.000000
# mean   550354.535113  5.439602e+07                            0.368818
# std    258945.047642  3.846377e+07                            1.218842
# min    100060.000000  3.780000e+02                            0.000000
# 25%    326864.000000  2.346142e+07                            0.000000
# 50%    553228.000000  4.589360e+07                            0.000000
# 75%    773081.250000  8.749489e+07                            0.000000
# max    999944.000000  1.894815e+08                           40.000000
#
#        emergency_visits_in_previous_year  inpatient_visits_in_previous_year  \
# count                       30530.000000                       30530.000000
# mean                            0.201539                           0.624861
# std                             0.974719                           1.252473
# min                             0.000000                           0.000000
# 25%                             0.000000                           0.000000
# 50%                             0.000000                           0.000000
# 75%                             0.000000                           1.000000
# max                            64.000000                          16.000000
#
#        average_pulse_bpm  length_of_stay_in_hospital  number_lab_tests  \
# count       30530.000000                30530.000000      30530.000000
# mean           99.633180                    4.407566         43.095611
# std            23.032567                    2.976634         19.747857
# min            60.000000                    1.000000          1.000000
# 25%            80.000000                    2.000000         32.000000
# 50%           100.000000                    4.000000         44.000000
# 75%           119.000000                    6.000000         57.000000
# max           139.000000                   14.000000        132.000000
#
#        non_lab_procedures  number_of_medications  number_diagnoses
# count        30530.000000           30530.000000      30530.000000
# mean             1.336947              16.083426          7.426302
# std              1.703830               8.139532          1.923772
# min              0.000000               1.000000          1.000000
# 25%              0.000000              10.000000          6.000000
# 50%              1.000000              15.000000          8.000000
# 75%              2.000000              20.000000          9.000000
# max              6.000000              81.000000         16.000000

# %%
train.describe()
# Out:
#         encounter_id    patient_id  outpatient_visits_in_previous_year  \
# count   71236.000000  7.123600e+04                        71236.000000
# mean   548798.623716  5.430228e+07                            0.369588
# std    259704.723154  3.879585e+07                            1.287469
# min    100000.000000  1.350000e+02                            0.000000
# 25%    323118.500000  2.339651e+07                            0.000000
# 50%    548370.000000  4.530563e+07                            0.000000
# 75%    774058.500000  8.755837e+07                            0.000000
# max    999980.000000  1.895026e+08                           42.000000
#
#        emergency_visits_in_previous_year  inpatient_visits_in_previous_year  \
# count                       71236.000000                       71236.000000
# mean                            0.196249                           0.640154
# std                             0.910854                           1.267271
# min                             0.000000                           0.000000
# 25%                             0.000000                           0.000000
# 50%                             0.000000                           0.000000
# 75%                             0.000000                           1.000000
# max                            76.000000                          21.000000
#
#        average_pulse_bpm  length_of_stay_in_hospital  number_lab_tests  \
# count       71236.000000                71236.000000      71236.000000
# mean           99.611222                    4.391024         43.095654
# std            23.040521                    2.988739         19.642919
# min            60.000000                    1.000000          1.000000
# 25%            80.000000                    2.000000         31.000000
# 50%           100.000000                    4.000000         44.000000
# 75%           119.000000                    6.000000         57.000000
# max           139.000000                   14.000000        121.000000
#
#        non_lab_procedures  number_of_medications  number_diagnoses
# count        71236.000000           71236.000000      71236.000000
# mean             1.340923              15.995452          7.421023
# std              1.706664               8.122347          1.937809
# min              0.000000               1.000000          1.000000
# 25%              0.000000              10.000000          6.000000
# 50%              1.000000              15.000000          8.000000
# 75%              2.000000              20.000000          9.000000
# max              6.000000              75.000000         16.000000

# %%
sample_submission['readmitted_binary'].value_counts()
# Out:
# No     15335
# Yes    15195
# Name: readmitted_binary, dtype: int64

# %%
test.corr(method = 'pearson')
# Out:
#                                     encounter_id  patient_id  \
# encounter_id                            1.000000   -0.032390
# patient_id                             -0.032390    1.000000
# outpatient_visits_in_previous_year     -0.000065    0.108780
# emergency_visits_in_previous_year      -0.011630    0.059459
# inpatient_visits_in_previous_year       0.000187    0.012036
# average_pulse_bpm                      -0.010829   -0.004827
# length_of_stay_in_hospital              0.004192   -0.023426
# number_lab_tests                        0.014150    0.016548
# non_lab_procedures                     -0.003126   -0.009761
# number_of_medications                  -0.002419    0.017303
# number_diagnoses                       -0.008561    0.232030
#
#                                     outpatient_visits_in_previous_year  \
# encounter_id                                                 -0.000065
# patient_id                                                    0.108780
# outpatient_visits_in_previous_year                            1.000000
# emergency_visits_in_previous_year                             0.096960
# inpatient_visits_in_previous_year                             0.116707
# average_pulse_bpm                                            -0.008089
# length_of_stay_in_hospital                                   -0.013590
# number_lab_tests                                             -0.011182
# non_lab_procedures                                           -0.032225
# number_of_medications                                         0.047927
# number_diagnoses                                              0.097227
#
#                                     emergency_visits_in_previous_year  \
# encounter_id                                                -0.011630
# patient_id                                                   0.059459
# outpatient_visits_in_previous_year                           0.096960
# emergency_visits_in_previous_year                            1.000000
# inpatient_visits_in_previous_year                            0.255600
# average_pulse_bpm                                            0.010601
# length_of_stay_in_hospital                                  -0.010722
# number_lab_tests                                            -0.011531
# non_lab_procedures                                          -0.042114
# number_of_medications                                        0.007467
# number_diagnoses                                             0.051357
#
#                                     inpatient_visits_in_previous_year  \
# encounter_id                                                 0.000187
# patient_id                                                   0.012036
# outpatient_visits_in_previous_year                           0.116707
# emergency_visits_in_previous_year                            0.255600
# inpatient_visits_in_previous_year                            1.000000
# average_pulse_bpm                                            0.002179
# length_of_stay_in_hospital                                   0.069338
# number_lab_tests                                             0.031713
# non_lab_procedures                                          -0.067337
# number_of_medications                                        0.059536
# number_diagnoses                                             0.096935
#
#                                     average_pulse_bpm  \
# encounter_id                                -0.010829
# patient_id                                  -0.004827
# outpatient_visits_in_previous_year          -0.008089
# emergency_visits_in_previous_year            0.010601
# inpatient_visits_in_previous_year            0.002179
# average_pulse_bpm                            1.000000
# length_of_stay_in_hospital                  -0.000604
# number_lab_tests                             0.014450
# non_lab_procedures                           0.000368
# number_of_medications                       -0.004036
# number_diagnoses                             0.005583
#
#                                     length_of_stay_in_hospital  \
# encounter_id                                          0.004192
# patient_id                                           -0.023426
# outpatient_visits_in_previous_year                   -0.013590
# emergency_visits_in_previous_year                    -0.010722
# inpatient_visits_in_previous_year                     0.069338
# average_pulse_bpm                                    -0.000604
# length_of_stay_in_hospital                            1.000000
# number_lab_tests                                      0.322832
# non_lab_procedures                                    0.189335
# number_of_medications                                 0.470048
# number_diagnoses                                      0.218988
#
#                                     number_lab_tests  non_lab_procedures  \
# encounter_id                                0.014150           -0.003126
# patient_id                                  0.016548           -0.009761
# outpatient_visits_in_previous_year         -0.011182           -0.032225
# emergency_visits_in_previous_year          -0.011531           -0.042114
# inpatient_visits_in_previous_year           0.031713           -0.067337
# average_pulse_bpm                           0.014450            0.000368
# length_of_stay_in_hospital                  0.322832            0.189335
# number_lab_tests                            1.000000            0.065059
# non_lab_procedures                          0.065059            1.000000
# number_of_medications                       0.274969            0.380790
# number_diagnoses                            0.148147            0.072048
#
#                                     number_of_medications  number_diagnoses
# encounter_id                                    -0.002419         -0.008561
# patient_id                                       0.017303          0.232030
# outpatient_visits_in_previous_year               0.047927          0.097227
# emergency_visits_in_previous_year                0.007467          0.051357
# inpatient_visits_in_previous_year                0.059536          0.096935
# average_pulse_bpm                               -0.004036          0.005583
# length_of_stay_in_hospital                       0.470048          0.218988
# number_lab_tests                                 0.274969          0.148147
# non_lab_procedures                               0.380790          0.072048
# number_of_medications                            1.000000          0.261105
# number_diagnoses                                 0.261105          1.000000

# %%
train.corr(method = 'pearson')
# Out:
#                                     encounter_id  patient_id  \
# encounter_id                            1.000000   -0.036909
# patient_id                             -0.036909    1.000000
# outpatient_visits_in_previous_year     -0.004919    0.101239
# emergency_visits_in_previous_year      -0.000135    0.063721
# inpatient_visits_in_previous_year       0.006722    0.012676
# average_pulse_bpm                      -0.003858    0.004491
# length_of_stay_in_hospital              0.005079   -0.024378
# number_lab_tests                        0.000315    0.015690
# non_lab_procedures                     -0.000909   -0.018033
# number_of_medications                   0.006565    0.022089
# number_diagnoses                       -0.009655    0.224659
#
#                                     outpatient_visits_in_previous_year  \
# encounter_id                                                 -0.004919
# patient_id                                                    0.101239
# outpatient_visits_in_previous_year                            1.000000
# emergency_visits_in_previous_year                             0.089280
# inpatient_visits_in_previous_year                             0.103610
# average_pulse_bpm                                             0.004913
# length_of_stay_in_hospital                                   -0.007030
# number_lab_tests                                             -0.006146
# non_lab_procedures                                           -0.021830
# number_of_medications                                         0.044112
# number_diagnoses                                              0.092945
#
#                                     emergency_visits_in_previous_year  \
# encounter_id                                                -0.000135
# patient_id                                                   0.063721
# outpatient_visits_in_previous_year                           0.089280
# emergency_visits_in_previous_year                            1.000000
# inpatient_visits_in_previous_year                            0.271818
# average_pulse_bpm                                           -0.007844
# length_of_stay_in_hospital                                  -0.009223
# number_lab_tests                                             0.001985
# non_lab_procedures                                          -0.036403
# number_of_medications                                        0.015796
# number_diagnoses                                             0.057487
#
#                                     inpatient_visits_in_previous_year  \
# encounter_id                                                 0.006722
# patient_id                                                   0.012676
# outpatient_visits_in_previous_year                           0.103610
# emergency_visits_in_previous_year                            0.271818
# inpatient_visits_in_previous_year                            1.000000
# average_pulse_bpm                                            0.000458
# length_of_stay_in_hospital                                   0.075453
# number_lab_tests                                             0.042435
# non_lab_procedures                                          -0.065781
# number_of_medications                                        0.066215
# number_diagnoses                                             0.107992
#
#                                     average_pulse_bpm  \
# encounter_id                                -0.003858
# patient_id                                   0.004491
# outpatient_visits_in_previous_year           0.004913
# emergency_visits_in_previous_year           -0.007844
# inpatient_visits_in_previous_year            0.000458
# average_pulse_bpm                            1.000000
# length_of_stay_in_hospital                   0.002900
# number_lab_tests                             0.001046
# non_lab_procedures                          -0.001729
# number_of_medications                        0.001999
# number_diagnoses                             0.000141
#
#                                     length_of_stay_in_hospital  \
# encounter_id                                          0.005079
# patient_id                                           -0.024378
# outpatient_visits_in_previous_year                   -0.007030
# emergency_visits_in_previous_year                    -0.009223
# inpatient_visits_in_previous_year                     0.075453
# average_pulse_bpm                                     0.002900
# length_of_stay_in_hospital                            1.000000
# number_lab_tests                                      0.316575
# non_lab_procedures                                    0.192387
# number_of_medications                                 0.464457
# number_diagnoses                                      0.220691
#
#                                     number_lab_tests  non_lab_procedures  \
# encounter_id                                0.000315           -0.000909
# patient_id                                  0.015690           -0.018033
# outpatient_visits_in_previous_year         -0.006146           -0.021830
# emergency_visits_in_previous_year           0.001985           -0.036403
# inpatient_visits_in_previous_year           0.042435           -0.065781
# average_pulse_bpm                           0.001046           -0.001729
# length_of_stay_in_hospital                  0.316575            0.192387
# number_lab_tests                            1.000000            0.055058
# non_lab_procedures                          0.055058            1.000000
# number_of_medications                       0.265226            0.387917
# number_diagnoses                            0.154756            0.074452
#
#                                     number_of_medications  number_diagnoses
# encounter_id                                     0.006565         -0.009655
# patient_id                                       0.022089          0.224659
# outpatient_visits_in_previous_year               0.044112          0.092945
# emergency_visits_in_previous_year                0.015796          0.057487
# inpatient_visits_in_previous_year                0.066215          0.107992
# average_pulse_bpm                                0.001999          0.000141
# length_of_stay_in_hospital                       0.464457          0.220691
# number_lab_tests                                 0.265226          0.154756
# non_lab_procedures                               0.387917          0.074452
# number_of_medications                            1.000000          0.261705
# number_diagnoses                                 0.261705          1.000000

# %% [markdown]
# # Data pre-processing, data partition and scaling

# %%
sample_submission.set_index('encounter_id', inplace = True)

# %%
sample_submission
# Out:
#              readmitted_binary
# encounter_id
# 499502                      No
# 447319                      No
# 309126                     Yes
# 181183                     Yes
# 359339                      No
# ...                        ...
# 451150                      No
# 549298                     Yes
# 327586                     Yes
# 351214                     Yes
# 914270                     Yes
#
# [30530 rows x 1 columns]

# %%
for column in ['race', 'age', 'admission_type', 'discharge_disposition', 'admission_source']:
    train[column] = train[column].fillna('Unknown')
    test[column] = test[column].fillna('Unknown')

for column in ['glucose_test_result', 'a1c_test_result']:
    train[column] = train[column].fillna('None')
    test[column] = test[column].fillna('None')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71236 entries, 0 to 71235
# Data columns (total 31 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   encounter_id                           71236 non-null  int64
#  1   country                                71236 non-null  object
#  2   patient_id                             71236 non-null  int64
#  3   race                                   71236 non-null  object
#  4   gender                                 71236 non-null  object
#  5   age                                    71236 non-null  object
#  6   weight                                 71236 non-null  object
#  7   payer_code                             71236 non-null  object
#  8   outpatient_visits_in_previous_year     71236 non-null  int64
#  9   emergency_visits_in_previous_year      71236 non-null  int64
#  10  inpatient_visits_in_previous_year      71236 non-null  int64
#  11  admission_type                         71236 non-null  object
#  12  medical_specialty                      71236 non-null  object
#  13  average_pulse_bpm                      71236 non-null  int64
#  14  discharge_disposition                  71236 non-null  object
#  15  admission_source                       71236 non-null  object
#  16  length_of_stay_in_hospital             71236 non-null  int64
#  17  number_lab_tests                       71236 non-null  int64
#  18  non_lab_procedures                     71236 non-null  int64
#  19  number_of_medications                  71236 non-null  int64
#  20  primary_diagnosis                      71236 non-null  object
#  21  secondary_diagnosis                    71236 non-null  object
#  22  additional_diagnosis                   71236 non-null  object
#  23  number_diagnoses                       71236 non-null  int64
#  24  glucose_test_result                    71236 non-null  object
#  25  a1c_test_result                        71236 non-null  object
#  26  change_in_meds_during_hospitalization  71236 non-null  object
#  27  prescribed_diabetes_meds               71236 non-null  object
#  28  medication                             71236 non-null  object
#  29  readmitted_binary                      71236 non-null  object
#  30  readmitted_multiclass                  71236 non-null  object
# dtypes: int64(11), object(20)
# memory usage: 16.8+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30530 entries, 0 to 30529
# Data columns (total 29 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   encounter_id                           30530 non-null  int64
#  1   country                                30530 non-null  object
#  2   patient_id                             30530 non-null  int64
#  3   race                                   30530 non-null  object
#  4   gender                                 30530 non-null  object
#  5   age                                    30530 non-null  object
#  6   weight                                 30530 non-null  object
#  7   payer_code                             30530 non-null  object
#  8   outpatient_visits_in_previous_year     30530 non-null  int64
#  9   emergency_visits_in_previous_year      30530 non-null  int64
#  10  inpatient_visits_in_previous_year      30530 non-null  int64
#  11  admission_type                         30530 non-null  object
#  12  medical_specialty                      30530 non-null  object
#  13  average_pulse_bpm                      30530 non-null  int64
#  14  discharge_disposition                  30530 non-null  object
#  15  admission_source                       30530 non-null  object
#  16  length_of_stay_in_hospital             30530 non-null  int64
#  17  number_lab_tests                       30530 non-null  int64
#  18  non_lab_procedures                     30530 non-null  int64
#  19  number_of_medications                  30530 non-null  int64
#  20  primary_diagnosis                      30530 non-null  object
#  21  secondary_diagnosis                    30530 non-null  object
#  22  additional_diagnosis                   30530 non-null  object
#  23  number_diagnoses                       30530 non-null  int64
#  24  glucose_test_result                    30530 non-null  object
#  25  a1c_test_result                        30530 non-null  object
#  26  change_in_meds_during_hospitalization  30530 non-null  object
#  27  prescribed_diabetes_meds               30530 non-null  object
#  28  medication                             30530 non-null  object
# dtypes: int64(11), object(18)
# memory usage: 6.8+ MB

# %%
train
# Out:
#        encounter_id country  patient_id             race  gender      age  \
# 0            533253     USA       70110        Caucasian  Female  [70-80)
# 1            426224     USA    29775006  AfricanAmerican    Male  [50-60)
# 2            634063     USA    80729253        Caucasian  Female  [60-70)
# 3            890610     USA     2919042  AfricanAmerican    Male  [60-70)
# 4            654194     USA    84871971        Caucasian  Female  [70-80)
# ...             ...     ...         ...              ...     ...      ...
# 71231        660160     USA    24531381  AfricanAmerican  Female  [80-90)
# 71232        826429     USA     4663818  AfricanAmerican  Female  [70-80)
# 71233        332030     USA    23397147        Caucasian  Female  [60-70)
# 71234        757560     USA    52161750        Caucasian    Male  [60-70)
# 71235        459757     USA    88410897        Caucasian    Male  [70-80)
#
#       weight payer_code  outpatient_visits_in_previous_year  \
# 0          ?          ?                                   0
# 1          ?          ?                                   0
# 2          ?          ?                                   0
# 3          ?         MC                                   0
# 4          ?         HM                                   1
# ...      ...        ...                                 ...
# 71231      ?         MC                                   0
# 71232      ?          ?                                   0
# 71233      ?          ?                                   0
# 71234      ?         BC                                   0
# 71235      ?         BC                                   0
#
#        emergency_visits_in_previous_year  ...  secondary_diagnosis  \
# 0                                      0  ...                  276
# 1                                      0  ...                  785
# 2                                      0  ...                  135
# 3                                      0  ...                  562
# 4                                      0  ...                  599
# ...                                  ...  ...                  ...
# 71231                                  1  ...                  786
# 71232                                  0  ...                  197
# 71233                                  2  ...                  491
# 71234                                  0  ...                  157
# 71235                                  0  ...                  250
#
#       additional_diagnosis number_diagnoses  glucose_test_result  \
# 0                      466                8                 None
# 1                      162                9                 None
# 2                      250                6                 None
# 3                      455                5                 None
# 4                      428                9                 None
# ...                    ...              ...                  ...
# 71231                  250                9                 None
# 71232                  V66                6                 None
# 71233                  276                9                 >300
# 71234                250.8                5                 None
# 71235                  401                8                 None
#
#       a1c_test_result change_in_meds_during_hospitalization  \
# 0                None                                    No
# 1                None                                    No
# 2                None                                    Ch
# 3                None                                    No
# 4                None                                    No
# ...               ...                                   ...
# 71231              >7                                    Ch
# 71232              >7                                    Ch
# 71233            None                                    Ch
# 71234            None                                    Ch
# 71235            None                                    Ch
#
#        prescribed_diabetes_meds                             medication  \
# 0                            No                                     []
# 1                           Yes                            ['insulin']
# 2                           Yes             ['glimepiride', 'insulin']
# 3                            No                                     []
# 4                            No                                     []
# ...                         ...                                    ...
# 71231                       Yes  ['metformin', 'glyburide', 'insulin']
# 71232                       Yes             ['metformin', 'glyburide']
# 71233                       Yes               ['glyburide', 'insulin']
# 71234                       Yes               ['glyburide', 'insulin']
# 71235                       Yes                            ['insulin']
#
#        readmitted_binary  readmitted_multiclass
# 0                     No               >30 days
# 1                     No                     No
# 2                     No                     No
# 3                     No                     No
# 4                     No               >30 days
# ...                  ...                    ...
# 71231                 No                     No
# 71232                 No                     No
# 71233                Yes               <30 days
# 71234                 No                     No
# 71235                 No               >30 days
#
# [71236 rows x 31 columns]

# %%
test.set_index('encounter_id', inplace = True)

# %%
test
# Out:
#              country  patient_id             race  gender      age weight  \
# encounter_id
# 499502           USA   103232799        Caucasian    Male  [80-90)      ?
# 447319           USA    93395304        Caucasian    Male  [20-30)      ?
# 309126           USA     6281586  AfricanAmerican    Male  [30-40)      ?
# 181183           USA    67381308        Caucasian    Male  [50-60)      ?
# 359339           USA    71670204        Caucasian    Male  [60-70)      ?
# ...              ...         ...              ...     ...      ...    ...
# 451150           USA    85707450        Caucasian    Male  [70-80)      ?
# 549298           USA      328887        Caucasian    Male  [60-70)      ?
# 327586           USA    21915459        Caucasian  Female  [80-90)      ?
# 351214           USA    17823546        Caucasian    Male  Unknown      ?
# 914270           USA    42043239        Caucasian  Female  [60-70)      ?
#
#              payer_code  outpatient_visits_in_previous_year  \
# encounter_id
# 499502               HM                                   0
# 447319               HM                                   0
# 309126                ?                                   0
# 181183               BC                                   0
# 359339                ?                                   0
# ...                 ...                                 ...
# 451150               HM                                   0
# 549298                ?                                   0
# 327586                ?                                   0
# 351214               MC                                   0
# 914270               MD                                   0
#
#               emergency_visits_in_previous_year  \
# encounter_id
# 499502                                        0
# 447319                                        0
# 309126                                        0
# 181183                                        0
# 359339                                        0
# ...                                         ...
# 451150                                        0
# 549298                                        0
# 327586                                        0
# 351214                                        0
# 914270                                        0
#
#               inpatient_visits_in_previous_year  ... number_of_medications  \
# encounter_id                                     ...
# 499502                                        0  ...                    14
# 447319                                        1  ...                     7
# 309126                                        0  ...                    12
# 181183                                        0  ...                    16
# 359339                                        0  ...                    10
# ...                                         ...  ...                   ...
# 451150                                        0  ...                    11
# 549298                                        4  ...                    19
# 327586                                        0  ...                    22
# 351214                                        0  ...                    21
# 914270                                        1  ...                    11
#
#              primary_diagnosis  secondary_diagnosis additional_diagnosis  \
# encounter_id
# 499502                     491                  414                  250
# 447319                  250.13                   70                  794
# 309126                     786                250.6                  536
# 181183                     820                  873                 E884
# 359339                     599                  427                  414
# ...                        ...                  ...                  ...
# 451150                     584                  276                  276
# 549298                     428               250.83                  276
# 327586                     996                  403                  250
# 351214                     153                  780                  285
# 914270                     486                    ?                  428
#
#              number_diagnoses  glucose_test_result  a1c_test_result  \
# encounter_id
# 499502                      6                 None             None
# 447319                      7                 >300             None
# 309126                      6                 None             None
# 181183                      9                 None             None
# 359339                      9                 None             None
# ...                       ...                  ...              ...
# 451150                      9                 None             None
# 549298                      9                 None             None
# 327586                      6                 None             None
# 351214                      5                 None               >7
# 914270                      8                 None             None
#
#               change_in_meds_during_hospitalization  prescribed_diabetes_meds  \
# encounter_id
# 499502                                           No                       Yes
# 447319                                           No                        No
# 309126                                           No                       Yes
# 181183                                           Ch                       Yes
# 359339                                           No                       Yes
# ...                                             ...                       ...
# 451150                                           No                        No
# 549298                                           No                       Yes
# 327586                                           No                       Yes
# 351214                                           Ch                       Yes
# 914270                                           No                       Yes
#
#                                             medication
# encounter_id
# 499502                                   ['metformin']
# 447319                                              []
# 309126                                     ['insulin']
# 181183           ['metformin', 'glyburide', 'insulin']
# 359339                                   ['metformin']
# ...                                                ...
# 451150                                              []
# 549298                                     ['insulin']
# 327586                                     ['insulin']
# 351214        ['glipizide', 'pioglitazone', 'insulin']
# 914270                                ['pioglitazone']
#
# [30530 rows x 28 columns]

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30530 entries, 499502 to 914270
# Data columns (total 28 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   country                                30530 non-null  object
#  1   patient_id                             30530 non-null  int64
#  2   race                                   30530 non-null  object
#  3   gender                                 30530 non-null  object
#  4   age                                    30530 non-null  object
#  5   weight                                 30530 non-null  object
#  6   payer_code                             30530 non-null  object
#  7   outpatient_visits_in_previous_year     30530 non-null  int64
#  8   emergency_visits_in_previous_year      30530 non-null  int64
#  9   inpatient_visits_in_previous_year      30530 non-null  int64
#  10  admission_type                         30530 non-null  object
#  11  medical_specialty                      30530 non-null  object
#  12  average_pulse_bpm                      30530 non-null  int64
#  13  discharge_disposition                  30530 non-null  object
#  14  admission_source                       30530 non-null  object
#  15  length_of_stay_in_hospital             30530 non-null  int64
#  16  number_lab_tests                       30530 non-null  int64
#  17  non_lab_procedures                     30530 non-null  int64
#  18  number_of_medications                  30530 non-null  int64
#  19  primary_diagnosis                      30530 non-null  object
#  20  secondary_diagnosis                    30530 non-null  object
#  21  additional_diagnosis                   30530 non-null  object
#  22  number_diagnoses                       30530 non-null  int64
#  23  glucose_test_result                    30530 non-null  object
#  24  a1c_test_result                        30530 non-null  object
#  25  change_in_meds_during_hospitalization  30530 non-null  object
#  26  prescribed_diabetes_meds               30530 non-null  object
#  27  medication                             30530 non-null  object
# dtypes: int64(10), object(18)
# memory usage: 6.8+ MB

# %%
X = train.drop(['readmitted_binary','readmitted_multiclass'], axis = 1)
y = train['readmitted_binary']

# %%
X_train, X_val, y_train, y_val = train_test_split(X,y, test_size = 0.3, 
                                                  random_state = 0, 
                                                  stratify = y, 
                                                  shuffle = True)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49865 entries, 58848 to 63400
# Data columns (total 29 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   encounter_id                           49865 non-null  int64
#  1   country                                49865 non-null  object
#  2   patient_id                             49865 non-null  int64
#  3   race                                   49865 non-null  object
#  4   gender                                 49865 non-null  object
#  5   age                                    49865 non-null  object
#  6   weight                                 49865 non-null  object
#  7   payer_code                             49865 non-null  object
#  8   outpatient_visits_in_previous_year     49865 non-null  int64
#  9   emergency_visits_in_previous_year      49865 non-null  int64
#  10  inpatient_visits_in_previous_year      49865 non-null  int64
#  11  admission_type                         49865 non-null  object
#  12  medical_specialty                      49865 non-null  object
#  13  average_pulse_bpm                      49865 non-null  int64
#  14  discharge_disposition                  49865 non-null  object
#  15  admission_source                       49865 non-null  object
#  16  length_of_stay_in_hospital             49865 non-null  int64
#  17  number_lab_tests                       49865 non-null  int64
#  18  non_lab_procedures                     49865 non-null  int64
#  19  number_of_medications                  49865 non-null  int64
#  20  primary_diagnosis                      49865 non-null  object
#  21  secondary_diagnosis                    49865 non-null  object
#  22  additional_diagnosis                   49865 non-null  object
#  23  number_diagnoses                       49865 non-null  int64
#  24  glucose_test_result                    49865 non-null  object
#  25  a1c_test_result                        49865 non-null  object
#  26  change_in_meds_during_hospitalization  49865 non-null  object
#  27  prescribed_diabetes_meds               49865 non-null  object
#  28  medication                             49865 non-null  object
# dtypes: int64(11), object(18)
# memory usage: 11.4+ MB

# %%
X_train_num = X_train.select_dtypes(include=np.number).set_index(X_train.index)

X_train_cat = X_train.select_dtypes(exclude=np.number).set_index(X_train.index)

X_val_num = X_val.select_dtypes(include=np.number).set_index(X_val.index)

X_val_cat = X_val.select_dtypes(exclude=np.number).set_index(X_val.index)

# %%
from sklearn.preprocessing import MinMaxScaler

#call function
scaler = MinMaxScaler()

#fit to training data
scaler.fit(X_train_num)

#transform the data
X_train_num_scaled = scaler.transform(X_train_num) # this will return an array

#show results
X_train_num_scaled
# Out:
# array([[0.93048512, 0.60621956, 0.        , ..., 0.66666667, 0.36486486,
#         0.53333333],
#        [0.42292162, 0.2351976 , 0.        , ..., 0.16666667, 0.33783784,
#         0.53333333],
#        [0.84298762, 0.05003683, 0.        , ..., 0.        , 0.16216216,
#         0.33333333],
#        ...,
#        [0.16729038, 0.35481353, 0.        , ..., 0.        , 0.14864865,
#         0.33333333],
#        [0.35361675, 0.34677096, 0.04761905, ..., 0.        , 0.41891892,
#         0.53333333],
#        [0.76542812, 0.04852822, 0.        , ..., 0.        , 0.09459459,
#         0.06666667]])

# %%
X_train_num_scaled = pd.DataFrame(X_train_num_scaled, columns = X_train_num.columns).set_index(X_train.index)
X_train_num_scaled
# Out:
#        encounter_id  patient_id  outpatient_visits_in_previous_year  \
# 58848      0.930485    0.606220                            0.000000
# 69977      0.422922    0.235198                            0.000000
# 70394      0.842988    0.050037                            0.000000
# 34010      0.827900    0.388511                            0.000000
# 17436      0.795440    0.017122                            0.000000
# ...             ...         ...                                 ...
# 28553      0.638068    0.164257                            0.023810
# 49117      0.680300    0.319545                            0.000000
# 69029      0.167290    0.354814                            0.000000
# 19984      0.353617    0.346771                            0.047619
# 63400      0.765428    0.048528                            0.000000
#
#        emergency_visits_in_previous_year  inpatient_visits_in_previous_year  \
# 58848                                0.0                           0.157895
# 69977                                0.0                           0.052632
# 70394                                0.0                           0.000000
# 34010                                0.0                           0.157895
# 17436                                0.0                           0.105263
# ...                                  ...                                ...
# 28553                                0.0                           0.000000
# 49117                                0.0                           0.000000
# 69029                                0.0                           0.263158
# 19984                                0.0                           0.105263
# 63400                                0.0                           0.000000
#
#        average_pulse_bpm  length_of_stay_in_hospital  number_lab_tests  \
# 58848           0.455696                    0.846154          0.558333
# 69977           0.734177                    0.307692          0.558333
# 70394           0.253165                    0.846154          0.300000
# 34010           0.341772                    0.000000          0.058333
# 17436           0.240506                    0.230769          0.000000
# ...                  ...                         ...               ...
# 28553           0.607595                    0.076923          0.391667
# 49117           0.670886                    0.076923          0.283333
# 69029           0.000000                    0.153846          0.058333
# 19984           0.658228                    0.538462          0.341667
# 63400           0.873418                    0.153846          0.383333
#
#        non_lab_procedures  number_of_medications  number_diagnoses
# 58848            0.666667               0.364865          0.533333
# 69977            0.166667               0.337838          0.533333
# 70394            0.000000               0.162162          0.333333
# 34010            0.000000               0.162162          0.533333
# 17436            0.333333               0.243243          0.266667
# ...                   ...                    ...               ...
# 28553            0.333333               0.094595          0.533333
# 49117            1.000000               0.148649          0.333333
# 69029            0.000000               0.148649          0.333333
# 19984            0.000000               0.418919          0.533333
# 63400            0.000000               0.094595          0.066667
#
# [49865 rows x 11 columns]

# %%
X_val_num_scaled = scaler.transform(X_val_num)
X_val_num_scaled = pd.DataFrame(X_val_num_scaled, columns = X_val_num.columns).set_index(X_val.index)
X_val_num_scaled.head(3)
# Out:
#        encounter_id  patient_id  outpatient_visits_in_previous_year  \
# 46805      0.735093    0.953174                                 0.0
# 44454      0.217370    0.050641                                 0.0
# 37220      0.887829    0.190196                                 0.0
#
#        emergency_visits_in_previous_year  inpatient_visits_in_previous_year  \
# 46805                           0.000000                                0.0
# 44454                           0.000000                                0.0
# 37220                           0.013158                                0.0
#
#        average_pulse_bpm  length_of_stay_in_hospital  number_lab_tests  \
# 46805           0.544304                    0.000000          0.508333
# 44454           0.050633                    0.076923          0.450000
# 37220           1.000000                    0.076923          0.041667
#
#        non_lab_procedures  number_of_medications  number_diagnoses
# 46805                 0.0               0.243243          0.466667
# 44454                 0.0               0.067568          0.400000
# 37220                 0.0               0.054054          0.066667

# %% [markdown]
# 2. Feature Selection

# %% [markdown]
# 2. Feature Selection
#
# 2.1. Filter methods

# %% [markdown]
# 2.1.1. Univariate variables¶

# %%
X_train_num_scaled.var() == 0
X_train_num_scaled.var()
# Out:
# encounter_id                          0.083409
# patient_id                            0.041916
# outpatient_visits_in_previous_year    0.000937
# emergency_visits_in_previous_year     0.000159
# inpatient_visits_in_previous_year     0.004393
# average_pulse_bpm                     0.085094
# length_of_stay_in_hospital            0.053278
# number_lab_tests                      0.026703
# non_lab_procedures                    0.081016
# number_of_medications                 0.012002
# number_diagnoses                      0.016655
# dtype: float64

# %% [markdown]
# 2.1.2. Correlation indices

# %%
def cor_heatmap(cor):
    plt.figure(figsize=(12,10))
    sns.heatmap(data = cor, annot = True, cmap = plt.cm.Reds, fmt='.1')
    plt.show()

# %%
cor_spearman = X_train_num_scaled.corr(method = 'spearman')
cor_spearman
# Out:
#                                     encounter_id  patient_id  \
# encounter_id                            1.000000   -0.032645
# patient_id                             -0.032645    1.000000
# outpatient_visits_in_previous_year     -0.001200    0.150536
# emergency_visits_in_previous_year       0.003665    0.111454
# inpatient_visits_in_previous_year       0.011758    0.025932
# average_pulse_bpm                      -0.003766    0.007039
# length_of_stay_in_hospital              0.003481   -0.016274
# number_lab_tests                        0.001815    0.024201
# non_lab_procedures                      0.001868   -0.026006
# number_of_medications                   0.004159    0.045724
# number_diagnoses                       -0.013355    0.236345
#
#                                     outpatient_visits_in_previous_year  \
# encounter_id                                                 -0.001200
# patient_id                                                    0.150536
# outpatient_visits_in_previous_year                            1.000000
# emergency_visits_in_previous_year                             0.178220
# inpatient_visits_in_previous_year                             0.154602
# average_pulse_bpm                                             0.001971
# length_of_stay_in_hospital                                   -0.010435
# number_lab_tests                                             -0.021214
# non_lab_procedures                                           -0.028549
# number_of_medications                                         0.071215
# number_diagnoses                                              0.110199
#
#                                     emergency_visits_in_previous_year  \
# encounter_id                                                 0.003665
# patient_id                                                   0.111454
# outpatient_visits_in_previous_year                           0.178220
# emergency_visits_in_previous_year                            1.000000
# inpatient_visits_in_previous_year                            0.220046
# average_pulse_bpm                                           -0.000918
# length_of_stay_in_hospital                                  -0.004496
# number_lab_tests                                             0.002717
# non_lab_procedures                                          -0.045799
# number_of_medications                                        0.042574
# number_diagnoses                                             0.087742
#
#                                     inpatient_visits_in_previous_year  \
# encounter_id                                                 0.011758
# patient_id                                                   0.025932
# outpatient_visits_in_previous_year                           0.154602
# emergency_visits_in_previous_year                            0.220046
# inpatient_visits_in_previous_year                            1.000000
# average_pulse_bpm                                            0.003963
# length_of_stay_in_hospital                                   0.090294
# number_lab_tests                                             0.040902
# non_lab_procedures                                          -0.068571
# number_of_medications                                        0.097841
# number_diagnoses                                             0.136316
#
#                                     average_pulse_bpm  \
# encounter_id                                -0.003766
# patient_id                                   0.007039
# outpatient_visits_in_previous_year           0.001971
# emergency_visits_in_previous_year           -0.000918
# inpatient_visits_in_previous_year            0.003963
# average_pulse_bpm                            1.000000
# length_of_stay_in_hospital                   0.003634
# number_lab_tests                            -0.000998
# non_lab_procedures                          -0.005507
# number_of_medications                        0.004515
# number_diagnoses                            -0.002520
#
#                                     length_of_stay_in_hospital  \
# encounter_id                                          0.003481
# patient_id                                           -0.016274
# outpatient_visits_in_previous_year                   -0.010435
# emergency_visits_in_previous_year                    -0.004496
# inpatient_visits_in_previous_year                     0.090294
# average_pulse_bpm                                     0.003634
# length_of_stay_in_hospital                            1.000000
# number_lab_tests                                      0.334172
# non_lab_procedures                                    0.191304
# number_of_medications                                 0.462953
# number_diagnoses                                      0.241360
#
#                                     number_lab_tests  non_lab_procedures  \
# encounter_id                                0.001815            0.001868
# patient_id                                  0.024201           -0.026006
# outpatient_visits_in_previous_year         -0.021214           -0.028549
# emergency_visits_in_previous_year           0.002717           -0.045799
# inpatient_visits_in_previous_year           0.040902           -0.068571
# average_pulse_bpm                          -0.000998           -0.005507
# length_of_stay_in_hospital                  0.334172            0.191304
# number_lab_tests                            1.000000            0.017846
# non_lab_procedures                          0.017846            1.000000
# number_of_medications                       0.246866            0.347843
# number_diagnoses                            0.171316            0.070758
#
#                                     number_of_medications  number_diagnoses
# encounter_id                                     0.004159         -0.013355
# patient_id                                       0.045724          0.236345
# outpatient_visits_in_previous_year               0.071215          0.110199
# emergency_visits_in_previous_year                0.042574          0.087742
# inpatient_visits_in_previous_year                0.097841          0.136316
# average_pulse_bpm                                0.004515         -0.002520
# length_of_stay_in_hospital                       0.462953          0.241360
# number_lab_tests                                 0.246866          0.171316
# non_lab_procedures                               0.347843          0.070758
# number_of_medications                            1.000000          0.298093
# number_diagnoses                                 0.298093          1.000000

# %%
cor_heatmap(cor_spearman)

# %% [markdown]
# 2.1.3. Chi-Square for categorical data

# %%
def TestIndependence(X,y,var,alpha=0.05):        
    dfObserved = pd.crosstab(y,X) 
    chi2, p, dof, expected = stats.chi2_contingency(dfObserved.values)
    dfExpected = pd.DataFrame(expected, columns=dfObserved.columns, index = dfObserved.index)
    if p<alpha:
        result="{0} is IMPORTANT for Prediction".format(var)
    else:
        result="{0} is NOT an important predictor. (Discard {0} from model)".format(var)
    print(result)

# %%
for var in X_train_cat:
    TestIndependence(X_train_cat[var],y_train, var)
# Out:
# country is NOT an important predictor. (Discard country from model)
# race is IMPORTANT for Prediction
# gender is NOT an important predictor. (Discard gender from model)
# age is IMPORTANT for Prediction
# weight is NOT an important predictor. (Discard weight from model)
# payer_code is IMPORTANT for Prediction
# admission_type is IMPORTANT for Prediction
# medical_specialty is IMPORTANT for Prediction
# discharge_disposition is IMPORTANT for Prediction
# admission_source is IMPORTANT for Prediction
# primary_diagnosis is IMPORTANT for Prediction
# secondary_diagnosis is IMPORTANT for Prediction
# additional_diagnosis is IMPORTANT for Prediction
# glucose_test_result is IMPORTANT for Prediction
# a1c_test_result is IMPORTANT for Prediction
# change_in_meds_during_hospitalization is IMPORTANT for Prediction
# prescribed_diabetes_meds is IMPORTANT for Prediction
# medication is IMPORTANT for Prediction

# %% [markdown]
# 2.2. Wrapper Methods

# %% [markdown]
# 2.2.1. RFE

# %%
model = LogisticRegression()

# %%
rfe = RFE(estimator = model, n_features_to_select = 3)

# %%
X_rfe = rfe.fit_transform(X = X_train_num_scaled, y = y_train)

# %%
X_train_num_scaled.columns
# Out:
# Index(['encounter_id', 'patient_id', 'outpatient_visits_in_previous_year',
#        'emergency_visits_in_previous_year',
#        'inpatient_visits_in_previous_year', 'average_pulse_bpm',
#        'length_of_stay_in_hospital', 'number_lab_tests', 'non_lab_procedures',
#        'number_of_medications', 'number_diagnoses'],
#       dtype='object')

# %%
rfe.support_
# Out:
# array([False, False, False,  True,  True, False, False, False, False,
#        False,  True])

# %%
rfe.ranking_
# Out:
# array([8, 7, 4, 1, 1, 9, 3, 6, 5, 2, 1])

# %%
selected_features = pd.Series(rfe.support_, index = X_train_num_scaled.columns)
selected_features
# Out:
# encounter_id                          False
# patient_id                            False
# outpatient_visits_in_previous_year    False
# emergency_visits_in_previous_year      True
# inpatient_visits_in_previous_year      True
# average_pulse_bpm                     False
# length_of_stay_in_hospital            False
# number_lab_tests                      False
# non_lab_procedures                    False
# number_of_medications                 False
# number_diagnoses                       True
# dtype: bool

# %%
#no of features
nof_list=np.arange(1,8)            
high_score=0
#Variable to store the optimum features
nof=0           
train_score_list =[]
val_score_list = []

for n in range(len(nof_list)):
    model = LogisticRegression()
    
    rfe = RFE(estimator = model,n_features_to_select = nof_list[n])
    X_train_rfe = rfe.fit_transform(X_train_num_scaled,y_train)
    X_val_rfe = rfe.transform(X_val_num_scaled)
    model.fit(X_train_rfe,y_train)
    
    #storing results on training data
    train_score = model.score(X_train_rfe,y_train)
    train_score_list.append(train_score)
    
    #storing results on training data
    val_score = model.score(X_val_rfe,y_val)
    val_score_list.append(val_score)
    
    #check best score
    if(val_score >= high_score):
        high_score = val_score
        nof = nof_list[n]
print("Optimum number of features: %d" %nof)
print("Score with %d features: %f" % (nof, high_score))
# Out:
# Optimum number of features: 7
# Score with 7 features: 0.888962

# %%
plt.plot(list(range(1,8)), train_score_list, label="Score on Training Set", color='yellowgreen')
plt.plot(list(range(1,8)), val_score_list, label="Score on Test Set", color='dimgray')
plt.xlabel("Maximum Depth")
plt.ylabel("Score")
plt.legend()
plt.show()

# %%
#no of features
nof_list= np.arange(1,8)            
high_score=0
#Variable to store the optimum features
nof=0           
train_score_list =[]
val_score_list = []

for n in range(len(nof_list)):
    #call support vector machines classifier
    model = SVC(kernel = 'linear')
    
    #create RFE instance
    rfe = RFE(estimator = model,n_features_to_select = nof_list[n])
    
    #fit and transform for training data, transform for val data
    X_train_rfe = rfe.fit_transform(X_train_num_scaled,y_train)
    X_val_rfe = rfe.transform(X_val_num_scaled)
    
    model.fit(X_train_rfe,y_train)
    
    #storing results on training data
    train_score = model.score(X_train_rfe,y_train)
    train_score_list.append(train_score)
    
    #storing results on training data
    val_score = model.score(X_val_rfe,y_val)
    val_score_list.append(val_score)
    
    #check best score
    if(val_score > high_score):
        high_score = val_score
        nof = nof_list[n]
        
        #adding mention of variables to keep
        features_to_select = pd.Series(rfe.support_, index = X_train_num_scaled.columns)
        
print("Optimum number of features: %d" %nof)
print("Score with %d features: %f" % (nof, high_score))
print(f"Features to select: \n{features_to_select}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\duart\OneDrive\Ambiente de Trabalho\ProjectML.ipynb Cell 61 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/duart/OneDrive/Ambiente%20de%20Trabalho/ProjectML.ipynb#Y114sZmlsZQ%3D%3D?line=13'>14</a> rfe = RFE(estimator = model,n_features_to_select = nof_list[n])
#      <a href='vscode-notebook-cell:/c%3A/Users/duart/OneDrive/Ambiente%20de%20Trabalho/ProjectML.ipynb#Y114sZmlsZQ%3D%3D?line=15'>16</a> #fit and transform for training data, transform for val data
# ---> <a href='vscode-notebook-cell:/c%3A/Users/duart/OneDrive/Ambiente%20de%20Trabalho/ProjectML.ipynb#Y114sZmlsZQ%3D%3D?line=16'>17</a> X_train_rfe = rfe.fit_transform(X_train_num_scaled,y_train)
#      <a href='vscode-notebook-cell:/c%3A/Users/duart/OneDrive/Ambiente%20de%20Trabalho/ProjectML.ipynb#Y114sZmlsZQ%3D%3D?line=17'>18</a> X_val_rfe = rfe.transform(X_val_num_scaled)
#      <a href='vscode-notebook-cell:/c%3A/Users/duart/OneDrive/Ambiente%20de%20Trabalho/ProjectML.ipynb#Y114sZmlsZQ%3D%3D?line=19'>20</a> model.fit(X_train_rfe,y_train)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return_tuple = (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:918, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     915     return self.fit(X, **fit_params).transform(X)
#     916 else:
#     917     # fit method of arity 2 (supervised transformation)
# --> 918     return self.fit(X, y, **fit_params).transform(X)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sklearn\feature_selection\_rfe.py:249, in RFE.fit(self, X, y, **fit_params)
#     225 @_fit_context(
#     226     # RFE.estimator is not validated yet
#     227     prefer_skip_nested_validation=False
#     228 )
#     229 def fit(self, X, y, **fit_params):
#     230     """Fit the RFE model and then the underlying estimator on the selected features.
#     231
#     232     Parameters
#    (...)
#     247         Fitted estimator.
#     248     """
# --> 249     return self._fit(X, y, **fit_params)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sklearn\feature_selection\_rfe.py:297, in RFE._fit(self, X, y, step_score, **fit_params)
#     294 if self.verbose > 0:
#     295     print("Fitting estimator with %d features." % np.sum(support_))
# --> 297 estimator.fit(X[:, features], y, **fit_params)
#     299 # Get importance and rank them
#     300 importances = _get_feature_importances(
#     301     estimator,
#     302     self.importance_getter,
#     303     transform_func="square",
#     304 )
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sklearn\svm\_base.py:250, in BaseLibSVM.fit(self, X, y, sample_weight)
#     247     print("[LibSVM]", end="")
#     249 seed = rnd.randint(np.iinfo("i").max)
# --> 250 fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     251 # see comment on the other call to np.iinfo in this file
#     253 self.shape_fit_ = X.shape if hasattr(X, "shape") else (n_samples,)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sklearn\svm\_base.py:329, in BaseLibSVM._dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     315 libsvm.set_verbosity_wrap(self.verbose)
#     317 # we don't pass **self.get_params() to allow subclasses to
#     318 # add other parameters to __init__
#     319 (
#     320     self.support_,
#     321     self.support_vectors_,
#     322     self._n_support,
#     323     self.dual_coef_,
#     324     self.intercept_,
#     325     self._probA,
#     326     self._probB,
#     327     self.fit_status_,
#     328     self._num_iter,
# --> 329 ) = libsvm.fit(
#     330     X,
#     331     y,
#     332     svm_type=solver_type,
#     333     sample_weight=sample_weight,
#     334     # TODO(1.4): Replace "_class_weight" with "class_weight_"
#     335     class_weight=getattr(self, "_class_weight", np.empty(0)),
#     336     kernel=kernel,
#     337     C=self.C,
#     338     nu=self.nu,
#     339     probability=self.probability,
#     340     degree=self.degree,
#     341     shrinking=self.shrinking,
#     342     tol=self.tol,
#     343     cache_size=self.cache_size,
#     344     coef0=self.coef0,
#     345     gamma=self._gamma,
#     346     epsilon=self.epsilon,
#     347     max_iter=self.max_iter,
#     348     random_seed=random_seed,
#     349 )
#     351 self._warn_from_fit_status()
#
# KeyboardInterrupt:

# %%
plt.plot(list(range(1,8)), train_score_list, label="Score on Training Set", color='yellowgreen')
plt.plot(list(range(1,8)), val_score_list, label="Score on Test Set", color='dimgray')
plt.xlabel("Maximum Depth")
plt.ylabel("Score")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\duart\Downloads\ProjectML.ipynb Cell 62 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/duart/Downloads/ProjectML.ipynb#Y142sZmlsZQ%3D%3D?line=0'>1</a> plt.plot(list(range(1,8)), train_score_list, label="Score on Training Set", color='yellowgreen')
#       <a href='vscode-notebook-cell:/c%3A/Users/duart/Downloads/ProjectML.ipynb#Y142sZmlsZQ%3D%3D?line=1'>2</a> plt.plot(list(range(1,8)), val_score_list, label="Score on Test Set", color='dimgray')
#       <a href='vscode-notebook-cell:/c%3A/Users/duart/Downloads/ProjectML.ipynb#Y142sZmlsZQ%3D%3D?line=2'>3</a> plt.xlabel("Maximum Depth")
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
#    1687 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
#    1690     self.add_line(line)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:504, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     501     self.axes.yaxis.update_units(y)
#     503 if x.shape[0] != y.shape[0]:
# --> 504     raise ValueError(f"x and y must have same first dimension, but "
#     505                      f"have shapes {x.shape} and {y.shape}")
#     506 if x.ndim > 2 or y.ndim > 2:
#     507     raise ValueError(f"x and y can be no greater than 2D, but have "
#     508                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (7,) and (0,)

# %% [markdown]
# 2.3. Embedded Methods

# %% [markdown]
# 2.3.1. Lasso Regression

# %%
def plot_importance(coef,name):
    imp_coef = coef.sort_values()
    plt.figure(figsize=(8,10))
    imp_coef.plot(kind = "barh")
    plt.title("Feature importance using " + name + " Model")
    plt.show()

# %%
reg = LassoCV()

# %%
reg.fit(X_train_num_scaled, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\duart\OneDrive\Ambiente de Trabalho\ProjectML.ipynb Cell 67 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/duart/OneDrive/Ambiente%20de%20Trabalho/ProjectML.ipynb#Y123sZmlsZQ%3D%3D?line=0'>1</a> reg.fit(X_train_num_scaled, y_train)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:1551, in LinearModelCV.fit(self, X, y, sample_weight)
#    1540 else:
#    1541     # Need to validate separately here.
#    1542     # We can't pass multi_output=True because that would allow y to be
#    1543     # csr. We also want to allow y to be 64 or 32 but check_X_y only
#    1544     # allows to convert for 64.
#    1545     check_X_params = dict(
#    1546         accept_sparse="csc",
#    1547         dtype=[np.float64, np.float32],
#    1548         order="F",
#    1549         copy=copy_X,
#    1550     )
# -> 1551     X, y = self._validate_data(
#    1552         X, y, validate_separately=(check_X_params, check_y_params)
#    1553     )
#    1554     copy_X = False
#    1556 check_consistent_length(X, y)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:619, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     617     if "estimator" not in check_y_params:
#     618         check_y_params = {**default_check_params, **check_y_params}
# --> 619     y = check_array(y, input_name="y", **check_y_params)
#     620 else:
#     621     X, y = check_X_y(X, y, **check_params)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:917, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     915         array = xp.astype(array, dtype, copy=False)
#     916     else:
# --> 917         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     918 except ComplexWarning as complex_warning:
#     919     raise ValueError(
#     920         "Complex data not supported\n{}\n".format(array)
#     921     ) from complex_warning
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\_array_api.py:380, in _asarray_with_order(array, dtype, order, copy, xp)
#     378     array = numpy.array(array, order=order, dtype=dtype)
#     379 else:
# --> 380     array = numpy.asarray(array, order=order, dtype=dtype)
#     382 # At this point array is a NumPy ndarray. We convert it to an array
#     383 # container that is consistent with the input's namespace.
#     384 return xp.asarray(array)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\series.py:893, in Series.__array__(self, dtype)
#     846 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#     847     """
#     848     Return the values as a NumPy array.
#     849
#    (...)
#     891           dtype='datetime64[ns]')
#     892     """
# --> 893     return np.asarray(self._values, dtype)
#
# ValueError: could not convert string to float: 'No'

# %%
coef = pd.Series(reg.coef_, index = X_train_num_scaled.columns)
coef
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\duart\OneDrive\Ambiente de Trabalho\ProjectML.ipynb Cell 68 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/duart/OneDrive/Ambiente%20de%20Trabalho/ProjectML.ipynb#Y124sZmlsZQ%3D%3D?line=0'>1</a> coef = pd.Series(reg.coef_, index = X_train_num_scaled.columns)
#       <a href='vscode-notebook-cell:/c%3A/Users/duart/OneDrive/Ambiente%20de%20Trabalho/ProjectML.ipynb#Y124sZmlsZQ%3D%3D?line=1'>2</a> coef
#
# AttributeError: 'LassoCV' object has no attribute 'coef_'
